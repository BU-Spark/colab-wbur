# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Mass_Cases_Data.csv")
# Out:
# /Users/xukaiyan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 13 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   id                1048575 non-null  int64
#  1   court_department  1048575 non-null  object
#  2   court_division    1048575 non-null  object
#  3   court_location    1048575 non-null  object
#  4   case_title        1048575 non-null  object
#  5   case_type         1048575 non-null  object
#  6   case_status       1048575 non-null  object
#  7   status_date       1048116 non-null  datetime64[ns]
#  8   file_date         1048541 non-null  datetime64[ns]
#  9   Unnamed: 9        155 non-null      object
#  10  Unnamed: 10       32 non-null       object
#  11  Unnamed: 11       5 non-null        object
#  12  time_delta        1048114 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(9), timedelta64[ns](1)
# memory usage: 104.0+ MB

# %%
data.head()
data.tail()
# Out:
#               id court_department             court_division  \
# 1048570  1511581   District Court     Gardner District Court
# 1048571  1511582   District Court  Framingham District Court
# 1048572  1511584   District Court  Framingham District Court
# 1048573  1511586   District Court  Framingham District Court
# 1048574  1511587   District Court     Gardner District Court
#
#                     court_location  \
# 1048570     Gardner District Court
# 1048571  Framingham District Court
# 1048572  Framingham District Court
# 1048573  Framingham District Court
# 1048574     Gardner District Court
#
#                                                 case_title  \
# 1048570  0563CV000013 Mary Imogene Bassett Hospital v. ...
# 1048571  0549SP000085 Framingham Municipal Federal Cred...
# 1048572  0549SC000529 Boston Edison Company D/B/A Nstar...
# 1048573  0549SU000142 Meadow Apartments D/B/A Lord Ches...
# 1048574  0563SC000021 Commonwealth Receivables Inc v. B...
#
# ...

# %%
data["case_type"].value_counts()
# Out:
# Small Claims                     388016
# Civil                            249649
# Supplementary Process            113618
# Estates and Administration       101412
# Housing Court Summary Process     63675
#                                   ...
#  Edward J."                           1
#  Louise F"                            1
#  Patricia"                            1
#  George"                              1
#  Michael P"                           1
# Name: case_type, Length: 162, dtype: int64

# %%
data["court_department"].value_counts()
# Out:
# District Court              692786
# BMC                         114531
# Probate and Family Court    101417
# Housing Court                83171
# The Superior Court           50005
# Land Court Department         6665
# Name: court_department, dtype: int64

# %%
data['status_date'] = pd.to_datetime(data['status_date'], errors='coerce')
data['file_date'] = pd.to_datetime(data['file_date'], errors='coerce')

# %%
data['time_delta'] = (data.status_date - data.file_date)

# %%
data['time_delta'].describe()
# Out:
# count                        1048114
# mean     122 days 13:00:39.039264808
# std      273 days 00:53:38.587127344
# min            -40569 days +00:00:00
# 25%                 30 days 00:00:00
# 50%                 70 days 00:00:00
# 75%                133 days 00:00:00
# max              80456 days 00:00:00
# Name: time_delta, dtype: object
